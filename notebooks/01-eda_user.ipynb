# %%
import pandas as pd

# %%
users = pd.read_json('data/01_raw/users.jsonl', lines=True, dtype={
    "id_str": str,
})
users.set_index('id_str', inplace=True)
users
# Out:
#                                     id             name     screen_name  \
# id_str
# 2718436417                  2718436417          Gruuvan       DJGruuvan
# 792615528791703553  792615528791703600              C C     Cc54518746C
# 3287012484                  3287012484         Penelope    penelope20mn
# 93816184                      93816184         Soul Man      flipcritic
# 754884880996020225  754884880996020200   Nils Hillestad         Trmpwin
# ...                                ...              ...             ...
# 2734133342                  2734133342     Prince Sheri     sharoonp143
# 160302029                    160302029    Kelsey Cadden    kelseycadden
# 382361714                    382361714          bhavesh       bhaveshc_
# 3528645202                  3528645202       alisha mae  alishas_wonder
# 1686033637                  1686033637  melanie collins    possums4ever
#
#                                     location profile_location  \
# id_str
# ...
