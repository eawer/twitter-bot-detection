# %%
import joblib
import mlflow
import pandas as pd
import catboost as ctb
from kedro.io import PickleLocalDataSet
from catboost import CatBoostClassifier, cv, Pool
from sklearn.preprocessing import StandardScaler
from twitter_bot_detection.helpers import log_running_time
from sklearn.model_selection import train_test_split, StratifiedKFold
from eli5 import show_weights, explain_prediction, explain_weights_catboost
from sklearn.metrics import accuracy_score, classification_report, f1_score

# %%
X_train = pd.read_pickle("data/05_model_input/X_train.pkl")
X_test = pd.read_pickle("data/05_model_input/X_test.pkl")
y_train = pd.read_pickle("data/05_model_input/y_train.pkl")
y_test = pd.read_pickle("data/05_model_input/y_test.pkl")

# %%
# @log_running_time
def train_catboost(X_train: PickleLocalDataSet, X_test: PickleLocalDataSet, y_train: PickleLocalDataSet, y_test: PickleLocalDataSet, log=False) -> PickleLocalDataSet:
    params = {
        "iterations": 2500,
        "learning_rate": 0.02,
        "loss_function": 'Logloss',
        "random_seed": 1,
        "od_wait": 30,
        "od_type": "Iter",
        "thread_count": 8,
#         "cat_features": ["created_at_time"]
    }
    model = CatBoostClassifier(**params)
    features = X_train.columns.values
#     data = Pool(data=X_train, label=y_train, cat_features=params["cat_features"])

#     params = {"iterations": 100,
#               "depth": 2,
#               "loss_function": "Logloss",
#               "verbose": False}
# 
#     scores = cv(data, params, fold_count=3, verbose=200, plot="True", stratified=True)
    model.fit(
        X_train, y_train,
        eval_set=(X_test, y_test),
        verbose=200,
        plot=False,
    )
    
    y_pred = model.predict(X_test)
    
    f1 = f1_score(y_test, y_pred, average="weighted")        
    joblib.dump(model, 'data/06_models/catboost.pkl')
    
#     model.save_model('data/06_models/catboost', format="cbm", export_parameters=None, pool=None)
    
    print(classification_report(y_test, y_pred, digits=5))
    if log:
        mlflow.set_tracking_uri("databricks")
        mlflow.set_experiment("/Users/firefly.eugene@gmail.com/twitter-bot-detection")

        run_id = mlflow.search_runs(experiment_ids="3889491181315524", filter_string="tags.`mlflow.runName`='catboost'", run_view_type=1)["run_id"][0]
        mlflow.start_run(run_id=run_id, nested=False)
        with mlflow.start_run(nested=True):
            mlflow.set_tags({
                "lib": "catboost",
                "features": features,
            })

            mlflow.log_params(params)
            mlflow.log_metric("f1", f1, 1)
            mlflow.log_artifact('data/05_model_input/X_test.pkl')
        mlflow.end_run()
    
    return model

# %%
m = train_catboost(X_train, X_test, y_train, y_test, log=True);
# Out:
# 0:	learn: 0.6716830	test: 0.6717144	best: 0.6717144 (0)	total: 23ms	remaining: 57.5s
# 200:	learn: 0.2102663	test: 0.2164879	best: 0.2164879 (200)	total: 3.67s	remaining: 42s
# 400:	learn: 0.1849778	test: 0.1979392	best: 0.1979392 (400)	total: 7.46s	remaining: 39.1s
# 600:	learn: 0.1693293	test: 0.1902297	best: 0.1902297 (600)	total: 11.2s	remaining: 35.4s
# 800:	learn: 0.1569460	test: 0.1850337	best: 0.1850337 (800)	total: 14.9s	remaining: 31.7s
# 1000:	learn: 0.1476537	test: 0.1819563	best: 0.1819537 (999)	total: 18.6s	remaining: 27.9s
# 1200:	learn: 0.1395202	test: 0.1794074	best: 0.1794074 (1200)	total: 22.4s	remaining: 24.3s
# 1400:	learn: 0.1320143	test: 0.1776228	best: 0.1776183 (1392)	total: 26.1s	remaining: 20.5s
# 1600:	learn: 0.1248483	test: 0.1761560	best: 0.1761324 (1595)	total: 30s	remaining: 16.8s
# 1800:	learn: 0.1185706	test: 0.1753527	best: 0.1753527 (1800)	total: 33.7s	remaining: 13.1s
# 2000:	learn: 0.1126907	test: 0.1746323	best: 0.1746305 (1998)	total: 37.5s	remaining: 9.35s
# 2200:	learn: 0.1072804	test: 0.1739162	best: 0.1739162 (2200)	total: 41.2s	remaining: 5.6s
# Stopped by overfitting detector  (30 iterations wait)
#
# bestTest = 0.1737336899
# bestIteration = 2268
#
# Shrink model to first 2269 iterations.
#               precision    recall  f1-score   support
#
#            0    0.92988   0.97369   0.95128      4903
#            1    0.94074   0.85050   0.89335      2408
#
#     accuracy                        0.93311      7311
#    macro avg    0.93531   0.91209   0.92231      7311
# weighted avg    0.93346   0.93311   0.93220      7311

# %%
explain_weights_catboost(m, top=100)
# Out:
# Explanation(estimator='<catboost.core.CatBoostClassifier object at 0x7f9448419d10>', description='CatBoost feature importances; \nvalues are numbers 0 <= x <= 1; all values sum to 1.', error=None, method='feature importances', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='is_retweet_mean', weight=0.22257027, std=None, value=None), FeatureWeight(feature='followers_count', weight=0.057394892, std=None, value=None), FeatureWeight(feature='tweets', weight=0.04092228, std=None, value=None), FeatureWeight(feature='quotes_mean', weight=0.037471913, std=None, value=None), FeatureWeight(feature='tweets_per_day', weight=0.036995813, std=None, value=None), FeatureWeight(feature='replies_mean', weight=0.03408957, std=None, value=None), FeatureWeight(feature='statuses_count', weight=0.032396358, std=None, value=None), FeatureWeight(feature='verified', weight=0.031761315, std=None, value=None), FeatureWeight(feature='favourites_count', weight=0.030668063, std=None, value=None), FeatureWeight(feature='account_active_for_days', weight=0.030435435, std=None, value=None), FeatureWeight(feature='truncated_mean', weight=0.029526688, std=None, value=None), FeatureWeight(feature='mentions_mean', weight=0.02916971, std=None, value=None), FeatureWeight(feature='hashtags_mean', weight=0.02734786, std=None, value=None), FeatureWeight(feature='langs_nunique', weight=0.026840681, std=None, value=None), FeatureWeight(feature='friends_count', weight=0.02441364, std=None, value=None), FeatureWeight(feature='description_urls_count', weight=0.023408696, std=None, value=None), FeatureWeight(feature='hashtags_std', weight=0.02179656, std=None, value=None), FeatureWeight(feature='fr_to_flw_ratio', weight=0.021079747, std=None, value=None), FeatureWeight(feature='mentions_max', weight=0.019016407, std=None, value=None), FeatureWeight(feature='dominating_dayofweek_share', weight=0.01878571, std=None, value=None), FeatureWeight(feature='faw_to_tweets_ratio', weight=0.016172977, std=None, value=None), FeatureWeight(feature='mentions_std', weight=0.015199352, std=None, value=None), FeatureWeight(feature='hashtags_max', weight=0.015062461, std=None, value=None), FeatureWeight(feature='urls_std', weight=0.014854181, std=None, value=None), FeatureWeight(feature='listed_count', weight=0.013760975, std=None, value=None), FeatureWeight(feature='unique_sources', weight=0.012194339, std=None, value=None), FeatureWeight(feature='urls_mean', weight=0.012111272, std=None, value=None), FeatureWeight(feature='media_mean', weight=0.0115407165, std=None, value=None), FeatureWeight(feature='tweets_to_faw_ratio', weight=0.011467826, std=None, value=None), FeatureWeight(feature='media_std', weight=0.011027497, std=None, value=None), FeatureWeight(feature='favourites_per_day', weight=0.010696276, std=None, value=None), FeatureWeight(feature='sensitive_mean', weight=0.010559704, std=None, value=None), FeatureWeight(feature='symbols_mean', weight=0.010526086, std=None, value=None), FeatureWeight(feature='symbols_std', weight=0.008699735, std=None, value=None), FeatureWeight(feature='symbols_max', weight=0.0075091594, std=None, value=None), FeatureWeight(feature='created_at_time', weight=0.0074939756, std=None, value=None), FeatureWeight(feature='dominating_day_of_week', weight=0.006030497, std=None, value=None), FeatureWeight(feature='has_banner', weight=0.0029591522, std=None, value=None), FeatureWeight(feature='urls_max', weight=0.0015252185, std=None, value=None), FeatureWeight(feature='has_profile_url', weight=0.0012931952, std=None, value=None), FeatureWeight(feature='has_description', weight=0.0009341663, std=None, value=None), FeatureWeight(feature='has_location', weight=0.00087492255, std=None, value=None), FeatureWeight(feature='default_profile', weight=0.0006242619, std=None, value=None), FeatureWeight(feature='media_max', weight=0.0005521346, std=None, value=None), FeatureWeight(feature='default_profile_image', we ...

# %%
#eli5, shapley values
