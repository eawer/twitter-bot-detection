# %%
import mlflow
import pandas as pd
import catboost as ctb
from sklearn.metrics import accuracy_score, classification_report, f1_score
from catboost import CatBoostClassifier, cv, Pool
from sklearn.model_selection import train_test_split, StratifiedKFold
from eli5 import show_weights, explain_prediction, explain_weights_catboost
import shap

# %%
mlflow.set_tracking_uri("databricks")
mlflow.set_experiment("/Users/firefly.eugene@gmail.com/twitter-bot-detection")

# %%
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=1)

# %%
users = pd.read_pickle("../data/04_features/user_features.pkl")
users.fillna()

# %%
X = users.drop(columns=["label"])
y = users["label"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify)

# %%
train_pool = Pool(X_train, y_train, cat_features=["created_at_time"])
train_pool_slice = train_pool.slice([2, 3])

# %%
mlflow.start_run(run_name="catboost", nested=False)

# %%
with mlflow.start_run(nested=True):
    mlflow.set_tags({
        "lib": "catboost",
        "description": "tweets per day aded",
    })

    params = {
        "iterations": 2000,
        "learning_rate": 0.02,
        "loss_function": 'Logloss',
        "random_seed": 1,
        "od_wait": 30,
        "od_type": "Iter",
        "thread_count": 8,
        "cat_features": ["created_at_time",]
    }
    model = CatBoostClassifier(**params)
    
    model.fit(
        X_train, y_train,
        eval_set=(X_test, y_test),
        verbose=200,
        plot=False,
    )
    
    y_pred = model.predict(X_test)
    
    f1 = f1_score(y_test, y_pred, average="weighted")

    
    mlflow.log_params(params)       
    mlflow.log_metric("f1", f1, 1)
    mlflow.log_artifact('../data/04_features/user_features.pkl')
    
    model.save_model('../data/06_models/catboost', format="cbm", export_parameters=None, pool=None)
    print(classification_report(y_test, y_pred))
# Out:
# 0:	learn: 0.6803268	test: 0.6802663	best: 0.6802663 (0)	total: 12.6ms	remaining: 25.1s
# 200:	learn: 0.3064747	test: 0.3157352	best: 0.3157352 (200)	total: 2.55s	remaining: 22.8s
# 400:	learn: 0.2782812	test: 0.2936176	best: 0.2936176 (400)	total: 5.08s	remaining: 20.2s
# 600:	learn: 0.2642813	test: 0.2848709	best: 0.2848709 (600)	total: 7.64s	remaining: 17.8s
# 800:	learn: 0.2539880	test: 0.2797824	best: 0.2797824 (800)	total: 10.1s	remaining: 15.2s
# 1000:	learn: 0.2451079	test: 0.2771737	best: 0.2771737 (1000)	total: 12.7s	remaining: 12.7s
# 1200:	learn: 0.2372145	test: 0.2749893	best: 0.2749893 (1200)	total: 15.4s	remaining: 10.2s
# 1400:	learn: 0.2303988	test: 0.2737050	best: 0.2737050 (1400)	total: 17.9s	remaining: 7.66s
# 1600:	learn: 0.2239928	test: 0.2729066	best: 0.2729057 (1586)	total: 20.8s	remaining: 5.18s
# 1800:	learn: 0.2181514	test: 0.2720506	best: 0.2720462 (1799)	total: 23.5s	remaining: 2.6s
# Stopped by overfitting detector  (30 iterations wait)
#
# bestTest = 0.271764233
# bestIteration = 1887
#
# Shrink model to first 1888 iterations.
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      4948
#            1       0.86      0.77      0.81      2368
#
#     accuracy                           0.88      7316
#    macro avg       0.88      0.85      0.86      7316
# weighted avg       0.88      0.88      0.88      7316

# %%
explain_weights_catboost(model)
# Out:
# Explanation(estimator='<catboost.core.CatBoostClassifier object at 0x7f5ae41facd0>', description='CatBoost feature importances; \nvalues are numbers 0 <= x <= 1; all values sum to 1.', error=None, method='feature importances', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='followers_count', weight=0.14766647, std=None, value=None), FeatureWeight(feature='faw_to_tweets_ratio', weight=0.09084623, std=None, value=None), FeatureWeight(feature='tweets_per_day', weight=0.08652089, std=None, value=None), FeatureWeight(feature='tweets_to_faw_ratio', weight=0.086473845, std=None, value=None), FeatureWeight(feature='account_active_for_days', weight=0.08430524, std=None, value=None), FeatureWeight(feature='friends_count', weight=0.08109811, std=None, value=None), FeatureWeight(feature='favourites_count', weight=0.08085155, std=None, value=None), FeatureWeight(feature='statuses_count', weight=0.06463907, std=None, value=None), FeatureWeight(feature='verified', weight=0.06434256, std=None, value=None), FeatureWeight(feature='fr_to_flw_ratio', weight=0.051076002, std=None, value=None), FeatureWeight(feature='listed_count', weight=0.045424208, std=None, value=None), FeatureWeight(feature='favourites_per_day', weight=0.0348939, std=None, value=None), FeatureWeight(feature='description_urls_count', weight=0.028777307, std=None, value=None), FeatureWeight(feature='created_at_time', weight=0.016746148, std=None, value=None), FeatureWeight(feature='has_banner', weight=0.0140272025, std=None, value=None), FeatureWeight(feature='default_profile', weight=0.008454515, std=None, value=None), FeatureWeight(feature='has_profile_url', weight=0.0077117677, std=None, value=None), FeatureWeight(feature='listed_count_cat', weight=0.004599613, std=None, value=None), FeatureWeight(feature='default_profile_image', weight=0.0015453679, std=None, value=None), FeatureWeight(feature='has_description', weight=0.0, std=None, value=None)], remaining=2), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
mlflow.end_run()

# %%
sorted([(feature, round(score,2)) for score, feature in zip(model.feature_importances_, users.columns)], key=lambda x: x[1])
model.get_feature_importance(train_pool, "Interaction")[:5]
# Out:
# array([[ 1.        ,  5.        ,  2.82067909],
#        [ 2.        ,  5.        ,  2.78316243],
#        [ 1.        , 12.        ,  2.33374435],
#        [ 1.        , 16.        ,  2.26089442],
#        [ 1.        ,  2.        ,  2.22755059]])

# %%
import xgboost as xgb
# read in data
dtrain = xgb.DMatrix('demo/data/agaricus.txt.train')
dtest = xgb.DMatrix('demo/data/agaricus.txt.test')
# specify parameters via map
param = {'booster': 'dart',
         'max_depth': 5, 'learning_rate': 0.1,
         'objective': 'binary:logistic',
         'sample_type': 'uniform',
         'normalize_type': 'tree',
         'rate_drop': 0.1,
         'skip_drop': 0.5}
num_round = 50
bst = xgb.train(param, dtrain, num_round)
preds = bst.predict(dtest)
